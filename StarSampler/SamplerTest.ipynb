# %%
"""
Generate the mock dwarf galaxy kinematic data exactly as in Nguyen et al. (2022).

Requirements:
- Place star_sampler.py and template.py in your working directory.
- Ensure Python’s import path includes the directory (e.g. export PYTHONPATH=.).
- Install numpy and scipy.

The script below:
1. Samples DM + stellar parameters from the priors (App. A.4).
2. Uses StarSampler’s importance‐sampling to draw (r, vr, vt).
3. Converts to (x,y,z,vx,vy,vz) and projects onto a random line of sight.
4. Adds Gaussian noise (σv=0.1 km/s).
5. Repeats for 80 k training, 10 k validation, 10 k test samples.
6. Saves each split to .npy files.
"""

import numpy as np
import star_sampler as ss   # star_sampler.py
from template import Model  # template.py

def generate_galaxy_sample(params, mu_stars=100, vel_error=0.1, 
                           steps=50, resample_factor=10):
    # 1) draw number of tracer stars
    n_stars = np.random.poisson(mu_stars)
    # 2) initialize the DF model
    model = Model(**params)
    # 3) importance-sample (r, vr, vt) directly
    r_vr_vt_array = ss.impt_sample(
        model_class=model,
        steps=steps,
        resample_factor=resample_factor,
        samplesize=n_stars,
        replace=True,
        r_vr_vt=False  # return original (r, vr, vt) array
    )
    # unpack
    r = r_vr_vt_array[0]
    vr = r_vr_vt_array[1]
    vt = r_vr_vt_array[2]
    # 4) convert to Cartesian (x, y, z, vx, vy, vz)
    x, y, z, vx, vy, vz = ss.r_vr_vt_complete(np.vstack((r, vr, vt)).T)
    # 5) projection to (R, vlos)
    axis = np.random.choice(['x','y','z'])
    if axis == 'x':
        R = np.sqrt(y**2 + z**2); vlos = vx
    elif axis == 'y':
        R = np.sqrt(x**2 + z**2); vlos = vy
    else:  # 'z'
        R = np.sqrt(x**2 + y**2); vlos = vz
    # 6) add measurement noise
    vlos_noisy = vlos + np.random.normal(0, vel_error, size=vlos.shape)
    return R, vlos_noisy, params

def generate_dataset(n_samples, mu_stars=100, vel_error=0.1):
    data, labels = [], []
    for _ in range(n_samples):
        # Priors (App. A.4)
        rho0   = 10**np.random.uniform(5,   8)
        rs     = 10**np.random.uniform(-1,  np.log10(5))
        gamma  = np.random.uniform(-1,     2)
        r_star = np.random.uniform(0.2*rs, 1*rs)
        r_a    = np.random.uniform(0.5*r_star, 2*r_star)
        params = dict(rho0=rho0, rs=rs, gamma=gamma,
                      r_star=r_star, r_a=r_a)
        R, vlos, _ = generate_galaxy_sample(params, mu_stars, vel_error)
        data.append((R, vlos))
        labels.append(params)
    return data, labels

# Generate and save splits
train_data, train_labels = generate_dataset(80000)
val_data,   val_labels   = generate_dataset(10000)
test_data,  test_labels  = generate_dataset(10000) 

np.save('train_data.npy', train_data)
np.save('train_labels.npy', train_labels)
np.save('val_data.npy',   val_data)
np.save('val_labels.npy',   val_labels)
np.save('test_data.npy',  test_data)
np.save('test_labels.npy',  test_labels)

print("Mock datasets generated and saved!")
# Out:
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  27.437026023864746 sec
#   start drawing samples...
# Weight Variance:  0.13564402288538893 0.6457059869337294
#   sampling completed, time used:  0.27136898040771484 sec
# sample time:  27.70841908454895 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  26.210996866226196 sec
#   start drawing samples...
# Weight Variance:  0.14123349883070485 0.4352506260499648
#   sampling completed, time used:  0.23663616180419922 sec
# sample time:  26.447649002075195 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  21.476460933685303 sec
#   start drawing samples...
# Weight Variance:  0.1395607255341863 0.3755519089607159
#   sampling completed, time used:  0.1662430763244629 sec
# sample time:  21.64273500442505 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  27.44390606880188 sec
#   start drawing samples...
# Weight Variance:  0.13442086461389624 0.32427445665947646
#   sampling completed, time used:  0.23315787315368652 sec
# sample time:  27.677078008651733 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  23.735340118408203 sec
#   start drawing samples...
# Weight Variance:  0.15742552200582113 0.4714949985093093
#   sampling completed, time used:  0.21387982368469238 sec
# sample time:  23.94923710823059 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  23.410901069641113 sec
#   start drawing samples...
# Weight Variance:  0.13938992720434265 0.3108660135133103
#   sampling completed, time used:  0.2177290916442871 sec
# sample time:  23.628677129745483 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  28.190743923187256 sec
#   start drawing samples...
# Weight Variance:  0.14470651546092866 0.5142135166084787
#   sampling completed, time used:  0.21134328842163086 sec
# sample time:  28.402103900909424 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  30.287489891052246 sec
#   start drawing samples...
# Weight Variance:  0.12564453128445724 0.6663616301764619
#   sampling completed, time used:  0.27360987663269043 sec
# sample time:  30.561124801635742 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  30.277310132980347 sec
#   start drawing samples...
# Weight Variance:  0.10622378510507666 0.7538887631495435
#   sampling completed, time used:  0.2946770191192627 sec
# sample time:  30.572004079818726 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  32.383832931518555 sec
#   start drawing samples...
# Weight Variance:  0.10350501899196114 0.7679622268892999
#   sampling completed, time used:  0.2453629970550537 sec
# sample time:  32.62921094894409 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  26.46526527404785 sec
#   start drawing samples...
# Weight Variance:  0.13831405379268222 0.537765917034666
#   sampling completed, time used:  0.25810790061950684 sec
# sample time:  26.723411321640015 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  25.342156171798706 sec
#   start drawing samples...
# Weight Variance:  0.13471154487636566 0.31076006134559464
#   sampling completed, time used:  0.1745610237121582 sec
# sample time:  25.51673126220703 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  16.566803216934204 sec
#   start drawing samples...
# Weight Variance:  0.15779882178920682 0.39719924686263125
#   sampling completed, time used:  0.16769790649414062 sec
# sample time:  16.73451590538025 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  18.791263103485107 sec
#   start drawing samples...
# Weight Variance:  0.1374656221845296 0.33306695023179966
#   sampling completed, time used:  0.15236210823059082 sec
# sample time:  18.94364023208618 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  27.73162531852722 sec
#   start drawing samples...
# Weight Variance:  0.15986635465564258 0.46172719980320753
#   sampling completed, time used:  0.2612287998199463 sec
# sample time:  27.99286699295044 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  19.812299013137817 sec
#   start drawing samples...
# Weight Variance:  0.14022817872247215 0.3758915081849563
#   sampling completed, time used:  0.1830599308013916 sec
# sample time:  19.995375871658325 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  23.08822512626648 sec
#   start drawing samples...
# Weight Variance:  0.1339612219542971 0.3269928836891319
#   sampling completed, time used:  0.20569205284118652 sec
# sample time:  23.294149160385132 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  18.009138107299805 sec
#   start drawing samples...
# Weight Variance:  0.11747636562262974 0.2522937096170433
#   sampling completed, time used:  0.1779940128326416 sec
# sample time:  18.187186241149902 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  24.977149963378906 sec
#   start drawing samples...
# Weight Variance:  0.14216059002581466 0.4875768080738794
#   sampling completed, time used:  0.18119096755981445 sec
# sample time:  25.15835404396057 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  28.863567113876343 sec
#   start drawing samples...
# Weight Variance:  0.09382002536521986 0.7821888130507433
#   sampling completed, time used:  0.24025917053222656 sec
# sample time:  29.10384726524353 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  27.0932879447937 sec
#   start drawing samples...
# Weight Variance:  0.002210429843967746 0.9960404584820055
#   sampling completed, time used:  0.21759414672851562 sec
# sample time:  27.310895919799805 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  29.06945300102234 sec
#   start drawing samples...
# Weight Variance:  0.14452285079462024 0.46559844678287293
#   sampling completed, time used:  0.2445518970489502 sec
# sample time:  29.314021110534668 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  29.36318016052246 sec
#   start drawing samples...
# Weight Variance:  0.14359682677665422 0.5009297282661858
#   sampling completed, time used:  0.27913999557495117 sec
# sample time:  29.642336130142212 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  15.74172592163086 sec
#   start drawing samples...
# Weight Variance:  0.12864734873281508 0.28575164737945735
#   sampling completed, time used:  0.22805118560791016 sec
# sample time:  15.969794988632202 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  24.764644145965576 sec
#   start drawing samples...
# Weight Variance:  0.15705841453771857 0.4686872507686204
#   sampling completed, time used:  0.23183894157409668 sec
# sample time:  24.996497869491577 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  29.77324891090393 sec
#   start drawing samples...
# Weight Variance:  0.0818510081486312 0.8167107418842544
#   sampling completed, time used:  0.27901697158813477 sec
# sample time:  30.05228281021118 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  35.49949312210083 sec
#   start drawing samples...
# Weight Variance:  0.13605230005135205 0.6306941536928728
#   sampling completed, time used:  0.28635501861572266 sec
# sample time:  35.78586483001709 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  20.749217987060547 sec
#   start drawing samples...
# Weight Variance:  0.13472082430171853 0.3115277753638034
#   sampling completed, time used:  0.1895291805267334 sec
# sample time:  20.93876028060913 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  20.3438081741333 sec
#   start drawing samples...
# Weight Variance:  0.1566985675113589 0.41653088060167903
#   sampling completed, time used:  0.15843892097473145 sec
# sample time:  20.50226616859436 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  27.066170930862427 sec
#   start drawing samples...
# Weight Variance:  0.15195206797249672 0.39291906214297634
#   sampling completed, time used:  0.2505810260772705 sec
# sample time:  27.316766023635864 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  30.7697970867157 sec
#   start drawing samples...
# Weight Variance:  0.043651187177850666 0.9268959746229247
#   sampling completed, time used:  0.1903231143951416 sec
# sample time:  30.960134267807007 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  17.547813892364502 sec
#   start drawing samples...
# Weight Variance:  0.15092394029622333 0.3780839736766123
#   sampling completed, time used:  0.12726187705993652 sec
# sample time:  17.675092935562134 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  19.800111293792725 sec
#   start drawing samples...
# Weight Variance:  0.14186076103097442 0.33818278653037
#   sampling completed, time used:  0.16222190856933594 sec
# sample time:  19.96235227584839 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  17.610618829727173 sec
#   start drawing samples...
# Weight Variance:  0.1545394700585353 0.40692707671788686
#   sampling completed, time used:  0.12740707397460938 sec
# sample time:  17.73803973197937 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  16.290100812911987 sec
#   start drawing samples...
# Weight Variance:  0.1236029575884126 0.26396837810897245
#   sampling completed, time used:  0.11595702171325684 sec
# sample time:  16.406074047088623 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  29.495488166809082 sec
#   start drawing samples...
# Weight Variance:  0.1111548512292303 0.7211115638346933
#   sampling completed, time used:  0.25383710861206055 sec
# sample time:  29.749340295791626 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  18.595017433166504 sec
#   start drawing samples...
# Weight Variance:  0.13738442257320208 0.3234997177833986
#   sampling completed, time used:  0.16182875633239746 sec
# sample time:  18.75686025619507 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  14.74691891670227 sec
#   start drawing samples...
# Weight Variance:  0.15064241908964962 0.35402010865747413
#   sampling completed, time used:  0.14717602729797363 sec
# sample time:  14.894109010696411 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  32.846632957458496 sec
#   start drawing samples...
# Weight Variance:  0.1462680283203108 0.5396096178412967
#   sampling completed, time used:  0.19889116287231445 sec
# sample time:  33.045618295669556 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  25.692326068878174 sec
#   start drawing samples...
# Weight Variance:  0.14217317105307684 0.38943066248647434
#   sampling completed, time used:  0.20620393753051758 sec
# sample time:  25.89854407310486 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  22.79279899597168 sec
#   start drawing samples...
# Weight Variance:  0.12395258595457397 0.2768204409807449
#   sampling completed, time used:  0.19632506370544434 sec
# sample time:  22.989137887954712 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
#   complete proposal function, time used:  30.139604091644287 sec
#   start drawing samples...
# Weight Variance:  0.15549229269236803 0.5672542910521814
#   sampling completed, time used:  0.24310898780822754 sec
# sample time:  30.382729053497314 sec
# ------------------------------------
#
# Using importance sampling...
#   building proposal step function...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 72
#      69     return data, labels
#      71 # Generate and save splits
# ---> 72 train_data, train_labels = generate_dataset(80000)
#      73 val_data,   val_labels   = generate_dataset(10000)
#      74 test_data,  test_labels  = generate_dataset(10000)
#
# Cell In[17], line 66, in generate_dataset(n_samples, mu_stars, vel_error)
#      63 r_a    = np.random.uniform(0.5*r_star, 2*r_star)
#      64 params = dict(rho0=rho0, rs=rs, gamma=gamma,
#      65               r_star=r_star, r_a=r_a)
# ---> 66 R, vlos, _ = generate_galaxy_sample(params, mu_stars, vel_error)
#      67 data.append((R, vlos))
#      68 labels.append(params)
#
# Cell In[17], line 29, in generate_galaxy_sample(params, mu_stars, vel_error, steps, resample_factor)
#      27 model = Model(**params)
#      28 # 3) importance-sample (r, vr, vt) directly
# ---> 29 r_vr_vt_array = ss.impt_sample(
#      30     model_class=model,
#      31     steps=steps,
#      32     resample_factor=resample_factor,
#      33     samplesize=n_stars,
#      34     replace=True,
#      35     r_vr_vt=False  # return original (r, vr, vt) array
#      36 )
#      37 # unpack
#      38 r = r_vr_vt_array[0]
#
# File ~/Downloads/StarSampler-master/StarSampler/star_sampler.py:56, in impt_sample(model_class, steps, resample_factor, samplesize, replace, r_vr_vt, r_v, filename)
#      54
#      55
# ---> 56     ans = imptsample(model_class.DF, Xlim, Vlim, nX, nV, nA,
#      57                 [], [], steps, samplesize, resample_factor, replace,
#      58                 r_vr_vt, r_v, z_vr_vt=False)
#
# File ~/Downloads/StarSampler-master/StarSampler/star_sampler.py:193, in imptsample(fprob, rlim, vlim, Xn, Vn, An, model_param, context, steps, samplesize, rfactor, replace, r_vr_vt, r_v, z_vr_vt)
#     191 V = [ Vi-dv*0.5 for Vi in mgridlist[Xn:Vn+Xn]]
#     192 A = [ Ai-da*0.5 for Ai in mgridlist[Vn+Xn: var_num]]
# --> 193 fvalues = fprob(X, V) #, model_param, context)
#     194
#     195 #print 'max fvalues: ' , max(fvalues.flatten())
#
# File ~/Downloads/StarSampler-master/StarSampler/template.py:61, in DF(self, X, V)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Applications/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2372, in vectorize.__call__(self, *args, **kwargs)
#    2369     self._init_stage_2(*args, **kwargs)
#    2370     return self
# -> 2372 return self._call_as_normal(*args, **kwargs)
#
# File ~/Applications/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2365, in vectorize._call_as_normal(self, *args, **kwargs)
#    2362     vargs = [args[_i] for _i in inds]
#    2363     vargs.extend([kwargs[_n] for _n in names])
# -> 2365 return self._vectorize_call(func=func, args=vargs)
#
# File ~/Applications/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2455, in vectorize._vectorize_call(self, func, args)
#    2452 # Convert args to object arrays first
#    2453 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2455 outputs = ufunc(*inputs)
#    2457 if ufunc.nout == 1:
#    2458     res = asanyarray(outputs, dtype=otypes[0])
#
# File ~/Downloads/StarSampler-master/StarSampler/template.py:49, in _phi(self, r)
#      47 #r = X #unpack X
#      48 #v  = V #unpack V
# ---> 49
#      50 # calculate probability
#      51
#
# File ~/Applications/anaconda3/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File ~/Applications/anaconda3/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# File ~/Downloads/StarSampler-master/StarSampler/template.py:46, in integrand1(s)
#      44 Return: probability of coordinates in X, V
#      45 '''
# ---> 46
#      47 #r = X #unpack X
#      48 #v  = V #unpack V
#
# KeyboardInterrupt:
